# %% [markdown]
# The dataset contains 36733 instances of 11 sensor measures aggregated over one hour (by means of average or sum) from a gas turbine.
# The Dataset includes gas turbine parameters (such as Turbine Inlet Temperature and Compressor Discharge pressure) in addition to the ambient variables.
#
#
#
# Problem statement: predicting turbine energy yield (TEY) using ambient variables as features.
#
#
#
# Attribute Information:
#
# The explanations of sensor measurements and their brief statistics are given below.
#
# Variable (Abbr.) Unit Min Max Mean
# Ambient temperature (AT) C â€“6.23 37.10 17.71
# Ambient pressure (AP) mbar 985.85 1036.56 1013.07
# Ambient humidity (AH) (%) 24.08 100.20 77.87
# Air filter difference pressure (AFDP) mbar 2.09 7.61 3.93
# Gas turbine exhaust pressure (GTEP) mbar 17.70 40.72 25.56
# Turbine inlet temperature (TIT) C 1000.85 1100.89 1081.43
# Turbine after temperature (TAT) C 511.04 550.61 546.16
# Compressor discharge pressure (CDP) mbar 9.85 15.16 12.06
# Turbine energy yield (TEY) MWH 100.02 179.50 133.51
# Carbon monoxide (CO) mg/m3 0.00 44.10 2.37
# Nitrogen oxides (NOx) mg/m3 25.90 119.91 65.29

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 250
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder,OrdinalEncoder
from sklearn.metrics import classification_report
import tensorflow as ts
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('gas_turbines (1).csv')
df
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP      CO     NOX
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605  3.1547  82.722
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598  3.2363  82.776
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601  3.2012  82.468
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606  3.1923  82.670
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612  3.2484  82.311
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400  4.5186  79.559
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433  4.8470  79.917
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483  7.9632  90.912
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533  6.2494  93.227
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
df.describe()
# Out:
#                  AT           AP            AH          AFDP  ...           TEY           CDP            CO           NOX
# count  15039.000000  15039.00000  15039.000000  15039.000000  ...  15039.000000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294  ...    134.188464     12.102353      1.972499     68.190934
# std        7.574323      6.41076     13.793439      0.760197  ...     15.829717      1.103196      2.222206     10.470586
# min        0.522300    985.85000     30.344000      2.087400  ...    100.170000      9.904400      0.000388     27.765000
# 25%       11.408000   1008.90000     69.750000      3.723900  ...    127.985000     11.622000      0.858055     61.303500
# 50%       18.186000   1012.80000     82.266000      4.186200  ...    133.780000     12.025000      1.390200     66.601000
# 75%       23.862500   1016.90000     90.043500      4.550900  ...    140.895000     12.578000      2.160400     73.935500
# max       34.929000   1034.20000    100.200000      7.610600  ...    174.610000     15.081000     44.103000    119.890000
#
# [8 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
df.isna().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %% [markdown]
# # Spliting into train,test

# %%
x = df.drop(columns='TEY')
y = df['TEY']

# %%
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[-1.4397781 , -0.82664395,  1.28143632, ..., -1.35733078,
#          0.53201195,  1.3878449 ],
#        [-1.44960109, -0.74864748,  1.30456402, ..., -1.36367619,
#          0.56873344,  1.39300237],
#        [-1.43472138, -0.68625031,  1.21908576, ..., -1.36095673,
#          0.5529378 ,  1.36358566],
#        ...,
#        [-1.38626659, -1.07623263,  1.47697056, ..., -1.46792219,
#          2.69592467,  2.17006209],
#        [-1.42042259, -0.99823616,  1.44159024, ..., -1.42259784,
#          1.9246834 ,  2.391165  ],
#        [-1.43073409, -0.93583899,  1.33465179, ..., -1.37727349,
#          1.35415028,  2.32153907]])

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=143)

# %%
ann = Sequential()

ann.add(Dense(units=30,activation='sigmoid'))
ann.add(Dense(units=20,activation='relu'))

ann.add(Dense(units=1))

ann.compile(optimizer='adam',loss='mse')
ann.fit(xtrain,ytrain,validation_data=(xtest,ytest),epochs=50)
# Out:
# Epoch 1/50
# 376/376 [==============================] - 4s 5ms/step - loss: 11573.3340 - val_loss: 2820.3486
# Epoch 2/50
# 376/376 [==============================] - 1s 3ms/step - loss: 475.8462 - val_loss: 3.4895
# Epoch 3/50
# 376/376 [==============================] - 1s 3ms/step - loss: 1.9652 - val_loss: 1.4005
# Epoch 4/50
# 376/376 [==============================] - 1s 3ms/step - loss: 1.3078 - val_loss: 1.1399
# Epoch 5/50
# 376/376 [==============================] - 1s 3ms/step - loss: 1.1033 - val_loss: 0.9963
# Epoch 6/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.9841 - val_loss: 0.9204
# Epoch 7/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.9103 - val_loss: 0.8708
# Epoch 8/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.8572 - val_loss: 0.8327
# Epoch 9/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.8188 - val_loss: 0.8132
# Epoch 10/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.7878 - val_loss: 0.7801
# Epoch 11/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.7569 - val_loss: 0.7706
# Epoch 12/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.7328 - val_loss: 0.7427
# Epoch 13/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.7068 - val_loss: 0.7209
# Epoch 14/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6880 - val_loss: 0.6896
# Epoch 15/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6690 - val_loss: 0.6962
# Epoch 16/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6493 - val_loss: 0.6795
# Epoch 17/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6423 - val_loss: 0.6372
# Epoch 18/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6298 - val_loss: 0.6335
# Epoch 19/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6223 - val_loss: 0.6516
# Epoch 20/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6104 - val_loss: 0.6113
# Epoch 21/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.6028 - val_loss: 0.6408
# Epoch 22/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5951 - val_loss: 0.6061
# Epoch 23/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5867 - val_loss: 0.6427
# Epoch 24/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5811 - val_loss: 0.6432
# Epoch 25/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5769 - val_loss: 0.5839
# Epoch 26/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5799 - val_loss: 0.5781
# Epoch 27/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5692 - val_loss: 0.6165
# Epoch 28/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5605 - val_loss: 0.5728
# Epoch 29/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5617 - val_loss: 0.6262
# Epoch 30/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5591 - val_loss: 0.6206
# Epoch 31/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5555 - val_loss: 0.5570
# Epoch 32/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5444 - val_loss: 0.6133
# Epoch 33/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5396 - val_loss: 0.5721
# Epoch 34/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5456 - val_loss: 0.5916
# Epoch 35/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5458 - val_loss: 0.5343
# Epoch 36/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5302 - val_loss: 0.5359
# Epoch 37/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5407 - val_loss: 0.5413
# Epoch 38/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5320 - val_loss: 0.5308
# Epoch 39/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5210 - val_loss: 0.5275
# Epoch 40/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.5214 - val_loss: 0.5167
# Epoch 41/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5326 - val_loss: 0.5138
# Epoch 42/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5147 - val_loss: 0.5094
# Epoch 43/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.4976 - val_loss: 0.5782
# Epoch 44/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.4999 - val_loss: 0.5332
# Epoch 45/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.4990 - val_loss: 0.5050
# Epoch 46/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.5022 - val_loss: 0.4933
# Epoch 47/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.4935 - val_loss: 0.4855
# Epoch 48/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.4874 - val_loss: 0.5406
# Epoch 49/50
# 376/376 [==============================] - 1s 3ms/step - loss: 0.4830 - val_loss: 0.4829
# Epoch 50/50
# 376/376 [==============================] - 1s 2ms/step - loss: 0.4851 - val_loss: 0.4872

# %%
loss = pd.DataFrame(ann.history.history)
loss.plot()
# Out:
# <Axes: >

# %%
ypred = ann.predict(xtest)
ypred
# Out:
# 94/94 [==============================] - 1s 3ms/step
# array([[133.9294 ],
#        [132.7486 ],
#        [132.02396],
#        ...,
#        [112.03011],
#        [147.5636 ],
#        [153.77852]], dtype=float32)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,ypred)
# Out:
# 0.9980317720686995
